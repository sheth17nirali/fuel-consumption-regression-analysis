# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import Dataset

# %%
df = pd.read_csv("fuel.csv")
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 41192  14.982273         0.0        0.0        0.0      19      0.0        0
# 41193  14.330870         0.0        0.0        0.0      20      0.0        0
# ...

# %% [markdown]
# Data Cleaning

# %%
df= df.replace(0,np.nan)
df = df.dropna(axis='columns')
df.head()
# Out:
#    barrels08  city08  co2A  comb08  feScore  fuelCost08 fuelType  \
# 0  15.695714      19    -1      21       -1        1900  Regular
# 1  29.964545       9    -1      11       -1        3600  Regular
# 2  12.207778      23    -1      27       -1        1450  Regular
# 3  29.964545      10    -1      11       -1        3600  Regular
# 4  17.347895      17    -1      19       -1        2600  Premium
#
#           fuelType1  ghgScore  highway08     id        make  \
# 0  Regular Gasoline        -1         25      1  Alfa Romeo
# 1  Regular Gasoline        -1         14     10     Ferrari
# 2  Regular Gasoline        -1         33    100       Dodge
# 3  Regular Gasoline        -1         12   1000       Dodge
# 4  Premium Gasoline        -1         23  10000      Subaru
#
#                  model mpgData  phevBlended           VClass  year  \
# 0   Spider Veloce 2000       Y        False      Two Seaters  1985
# 1           Testarossa       N        False      Two Seaters  1985
# ...

# %%
df = df.drop('createdOn', axis='columns')
df = df.drop('modifiedOn', axis='columns')
df.head()
# Out:
#    barrels08  city08  co2A  comb08  feScore  fuelCost08 fuelType  \
# 0  15.695714      19    -1      21       -1        1900  Regular
# 1  29.964545       9    -1      11       -1        3600  Regular
# 2  12.207778      23    -1      27       -1        1450  Regular
# 3  29.964545      10    -1      11       -1        3600  Regular
# 4  17.347895      17    -1      19       -1        2600  Premium
#
#           fuelType1  ghgScore  highway08     id        make  \
# 0  Regular Gasoline        -1         25      1  Alfa Romeo
# 1  Regular Gasoline        -1         14     10     Ferrari
# 2  Regular Gasoline        -1         33    100       Dodge
# 3  Regular Gasoline        -1         12   1000       Dodge
# 4  Premium Gasoline        -1         23  10000      Subaru
#
#                  model mpgData  phevBlended           VClass  year
# 0   Spider Veloce 2000       Y        False      Two Seaters  1985
# 1           Testarossa       N        False      Two Seaters  1985
# ...

# %%
df
# Out:
#        barrels08  city08  co2A  comb08  feScore  fuelCost08 fuelType  \
# 0      15.695714      19    -1      21       -1        1900  Regular
# 1      29.964545       9    -1      11       -1        3600  Regular
# 2      12.207778      23    -1      27       -1        1450  Regular
# 3      29.964545      10    -1      11       -1        3600  Regular
# 4      17.347895      17    -1      19       -1        2600  Premium
# ...          ...     ...   ...     ...      ...         ...      ...
# 41192  14.982273      19    -1      22       -1        1800  Regular
# 41193  14.330870      20    -1      23       -1        1750  Regular
# 41194  15.695714      18    -1      21       -1        1900  Regular
# 41195  15.695714      18    -1      21       -1        1900  Regular
# 41196  18.311667      16    -1      18       -1        2750  Premium
#
#               fuelType1  ghgScore  highway08     id        make  \
# 0      Regular Gasoline        -1         25      1  Alfa Romeo
# ...
